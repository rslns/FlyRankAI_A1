# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
# ### 1) My lane as an ML task
#
# **Task type: Classification**
#
# My task is to classify content items based on their observed trend direction. The decision is which content items need attention first, so an editor can prioritize content that may need improvement.
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rslns/FlyRankAI_A1/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
# My lane is SEO/content performance. I want to classify content items based on their observed trend direction so that an editor can identify which content needs attention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
# **Target: `trend_pct`**
#
# I would predict the observed `trend_pct` for each content item. It is an observed outcome in the starter data, rather than a label I create from my own rule. A higher or lower trend percentage can help indicate which content items may need attention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
# ## Success metric
#
# **Metric: Mean Absolute Error (MAE)**
#
# A lower MAE means better predictions. It tells us, on average, how far our predicted `trend_pct` is from the observed `trend_pct`. This is easy to interpret because the error is measured in the same units as the target.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
# ## 4. The unit of analysis, as a real dataframe
#
# **Unit of analysis: one row = one pseudonymized content item.**
#
# Each row represents one content item with its search, traffic, content, and performance information.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
df.head()
print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# Rows: 30000
# Columns: 44

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
# ## Why ML beats a fixed rule here
#
# A fixed rule could use one threshold, such as flagging content when `trend_pct` is below a certain value. But content performance can depend on many factors, including search volume, impressions, position, content age, and content type. ML can learn patterns across multiple signals instead of relying on one manually chosen threshold. The output can help editors prioritize which content items need attention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
